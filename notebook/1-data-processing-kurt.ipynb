# %% [markdown]
# ## Cleaning and Preprocessing for Klook Data

# %% [markdown]
# **Import Libraries**

# %%
import spacy
import pandas as pd
import re
from decimal import Decimal
import numpy as np
import nltk
from nltk import word_tokenize, pos_tag
from nltk.corpus import stopwords
import inspect
from spacy import displacy

# %% [markdown]
# **Import Dataset**

# %%
df = pd.read_csv('Klook_PH.csv', encoding='ISO-8859-1')
df.head()
# Out:
#     region location             activity
# 0  Visayas  Palawan            Day trips  \
# 1  Visayas     Cebu            Canyoning
# 2  Visayas  Boracay           Boat tours
# 3  Visayas  Boracay  Sightseeing cruises
# 4  Visayas  Palawan           Boat tours
#
#                                                title
# 0                      Coron Super Ultimate Day Tour  \
# 1  Oslob Whale Shark Snorkeling and Badian Canyon...
# 2              Boracay Tour Package (Island Hopping)
# 3  Boracay Sunset Cruise with Kayak, Paddle Board...
# 4  Puerto Princesa Underground River Tour in Palawan
#
#                                          description    price  rating
# 0  Visit the highlights around Coron's breathtaki...  ? 1,590     4.7  \
# 1  Learn more about this activity's Enhanced Heal...  ? 3,635     4.7
# 2  Book this island tour package and discover Bor...    ? 900     4.5
# 3  Catch the spectacular Boracay sunset while cru...    ? 675     4.7
# 4  Explore the Puerto Princesa Underground River ...  ? 1,850     4.6
#
#     review_count            duration
# 0    684 reviews        9hr Duration
# 1    798 reviews       16hr Duration
# 2  3,947 reviews                 NaN
# 3  1,517 reviews  2hr 30min Duration
# 4  2,478 reviews  9hr 30min Duration

# %% [markdown]
# **Clean Features**

# %% [markdown]
# *Remove ? from price*

# %%
df['price'] = df['price'].str.replace('[?, ]', '', regex=True)
df['price'].head()
# Out:
# 0    1590
# 1    3635
# 2     900
# 3     675
# 4    1850
# Name: price, dtype: object

# %% [markdown]
# *Fill ratings of non-reviewed posts with 3.0 (average rating) and convert to float*

# %%
df['rating'] = df['rating'].apply(lambda x: round(x, 1))
df['rating'] = df['rating'].fillna(3.0)
df['rating']
# Out:
# 0      4.7
# 1      4.7
# 2      4.5
# 3      4.7
# 4      4.6
#       ...
# 167    3.0
# 168    3.0
# 169    3.0
# 170    3.0
# 171    3.0
# Name: rating, Length: 172, dtype: float64

# %% [markdown]
# *Convert review_counts to integer and fill Nan with 0. Used 1000 for 1k+ value, and so on*

# %%
df['review_count'] = df['review_count'].str.replace('+', '')
df['review_count'] = df['review_count'].str.replace(' reviews', '').replace('K', '000', regex=True)
df['review_count'] = df['review_count'].fillna(0)
df['review_count']
# Out:
# 0        684
# 1        798
# 2      3,947
# 3      1,517
# 4      2,478
#        ...
# 167        0
# 168        0
# 169        0
# 170        0
# 171        0
# Name: review_count, Length: 172, dtype: object

# %%
df
# Out:
#       region  location             activity
# 0    Visayas   Palawan            Day trips  \
# 1    Visayas      Cebu            Canyoning
# 2    Visayas   Boracay           Boat tours
# 3    Visayas   Boracay  Sightseeing cruises
# 4    Visayas   Palawan           Boat tours
# ..       ...       ...                  ...
# 167    Luzon     Bicol           Boat tours
# 168    Luzon     Tanay             Wildlife
# 169    Luzon     Tanay               Hiking
# 170  Visayas    Carles      Multi-day tours
# 171    Luzon  Antipolo              Camping
#
#                                                  title
# 0                        Coron Super Ultimate Day Tour  \
# 1    Oslob Whale Shark Snorkeling and Badian Canyon...
# 2                Boracay Tour Package (Island Hopping)
# 3    Boracay Sunset Cruise with Kayak, Paddle Board...
# 4    Puerto Princesa Underground River Tour in Palawan
# ..                                                 ...
# 167  Whaleshark Interaction with Firefly Expedition...
# 168                           Moolk Farm Tour in Rizal
# 169      Mount Batolusong Join In Day Hike from Manila
# 170        Gigantes Islands All In Package from Iloilo
# 171          Camping Experience at Gabriel's Sanctuary
#
#                                            description price  rating
# 0    Visit the highlights around Coron's breathtaki...  1590     4.7  \
# 1    Learn more about this activity's Enhanced Heal...  3635     4.7
# 2    Book this island tour package and discover Bor...   900     4.5
# 3    Catch the spectacular Boracay sunset while cru...   675     4.7
# 4    Explore the Puerto Princesa Underground River ...  1850     4.6
# ..                                                 ...   ...     ...
# 167  Donsol is best known for its whale watching wh...  2640     3.0
# 168  Experience the New Zealand of Tanay Rizal and ...   499     3.0
# 169  Start your morning by hiking to Mt. Batolusong...  1600     3.0
# 170  Enjoy this Ultimate Gigantes Islands All In Pa...  2799     3.0
# 171  Experience camping in the sky only an hour awa...   500     3.0
#
#     review_count                    duration
# 0            684                9hr Duration
# 1            798               16hr Duration
# 2          3,947                         NaN
# 3          1,517          2hr 30min Duration
# 4          2,478          9hr 30min Duration
# ..           ...                         ...
# 167            0         6hr - 10hr Duration
# 168            0                         NaN
# 169            0            1day(s) Duration
# 170            0  2day(s) - 3day(s) Duration
# 171            0                         NaN
#
# [172 rows x 9 columns]

# %% [markdown]
# *Standardize duration value into hours*

# %%
#remove (s) from day(S)
df['duration'] = df['duration'].str.replace(r'(s)', 's')

# Function to extract the number of hours
def extract_hours(duration):
    if isinstance(duration, str):
        hours = 0
        match = re.search(r'(\d+)(hr|hour|hours)', duration)
        if match:
            hours += int(match.group(1))

        match = re.search(r'(\d+)(min|minute|minutes)', duration)
        if match:
            hours += int(match.group(1)) / 60

        match = re.search(r'(\d+)(day|days)', duration)
        if match:
            hours += int(match.group(1)) * 24

        return hours
    else:
        return None

# Apply the function to the 'Duration' column
df['duration'] = df['duration'].apply(extract_hours)

df['duration']
# Out:
# 0       9.0
# 1      16.0
# 2       NaN
# 3       2.5
# 4       9.5
#        ...
# 167     6.0
# 168     NaN
# 169    24.0
# 170    48.0
# 171     NaN
# Name: duration, Length: 172, dtype: float64

# %%
df
# Out:
#       region  location             activity
# 0    Visayas   Palawan            Day trips  \
# 1    Visayas      Cebu            Canyoning
# 2    Visayas   Boracay           Boat tours
# 3    Visayas   Boracay  Sightseeing cruises
# 4    Visayas   Palawan           Boat tours
# ..       ...       ...                  ...
# 167    Luzon     Bicol           Boat tours
# 168    Luzon     Tanay             Wildlife
# 169    Luzon     Tanay               Hiking
# 170  Visayas    Carles      Multi-day tours
# 171    Luzon  Antipolo              Camping
#
#                                                  title
# 0                        Coron Super Ultimate Day Tour  \
# 1    Oslob Whale Shark Snorkeling and Badian Canyon...
# 2                Boracay Tour Package (Island Hopping)
# 3    Boracay Sunset Cruise with Kayak, Paddle Board...
# 4    Puerto Princesa Underground River Tour in Palawan
# ..                                                 ...
# 167  Whaleshark Interaction with Firefly Expedition...
# 168                           Moolk Farm Tour in Rizal
# 169      Mount Batolusong Join In Day Hike from Manila
# 170        Gigantes Islands All In Package from Iloilo
# 171          Camping Experience at Gabriel's Sanctuary
#
#                                            description price  rating
# 0    Visit the highlights around Coron's breathtaki...  1590     4.7  \
# 1    Learn more about this activity's Enhanced Heal...  3635     4.7
# 2    Book this island tour package and discover Bor...   900     4.5
# 3    Catch the spectacular Boracay sunset while cru...   675     4.7
# 4    Explore the Puerto Princesa Underground River ...  1850     4.6
# ..                                                 ...   ...     ...
# 167  Donsol is best known for its whale watching wh...  2640     3.0
# 168  Experience the New Zealand of Tanay Rizal and ...   499     3.0
# 169  Start your morning by hiking to Mt. Batolusong...  1600     3.0
# 170  Enjoy this Ultimate Gigantes Islands All In Pa...  2799     3.0
# 171  Experience camping in the sky only an hour awa...   500     3.0
#
#     review_count  duration
# 0            684       9.0
# 1            798      16.0
# 2          3,947       NaN
# 3          1,517       2.5
# 4          2,478       9.5
# ..           ...       ...
# 167            0       6.0
# 168            0       NaN
# 169            0      24.0
# 170            0      48.0
# 171            0       NaN
#
# [172 rows x 9 columns]

# %%
min_df = df[df['region'] == 'Mindanao']
min_df
# Out:
#        region location             activity
# 25   Mindanao  Siargao  Sightseeing cruises  \
# 30   Mindanao  Siargao            Day trips
# 45   Mindanao  Siargao            Day trips
# 48   Mindanao    Davao            Day trips
# 66   Mindanao    Davao            Day trips
# 83   Mindanao    Davao            Day trips
# 120  Mindanao  Siargao              Surfing
# 121  Mindanao  Siargao              Surfing
# 144  Mindanao    Davao            Day trips
#
#                                     title
# 25             Tri Island Tour in Siargao  \
# 30                      Siargao Land Tour
# 45   Sohoton-Bucas Grande Tour in Siargao
# 48                   Nature Tour in Davao
# 66             Samal Island Tour in Davao
# 83                        Davao City Tour
# 120               Siargao Surfing Lessons
# 121               Siargao Surfing Lessons
# 144               Highlands Tour in Davao
#
#                                            description price  rating
# 25   Go on a tri-island day trip in Siargao and exp...  1450     4.3  \
# 30   Dedicate your vacation pleasures with thrillin...  1900     4.6
# 45   Have the ultimate beach day in the Philippines...  3000     3.0
# 48   Go on an adventure in Davao with this Day Dava...  2550     5.0
# 66   Explore unique beaches and attractions of Sama...  2450     5.0
# 83   Explore the wonderful sights of Davao with thi...  1300     5.0
# 120  SIARGAO is the top surfing spot in the Philipp...   700     4.5
# 121  SIARGAO is the top surfing spot in the Philipp...   700     4.5
# 144  Enjoy breathtaking views in Davao with this 1 ...  2050     3.0
#
#     review_count  duration
# 25           396      24.0
# 30           229      24.0
# 45            84      24.0
# 48           183      24.0
# 66           137      24.0
# 83             2      24.0
# 120            4       1.0
# 121            4       1.0
# 144            0      24.0

# %% [markdown]
# *Remove see more in the descriptions*

# %%
df['description'] = df['description'].str.replace('See more', '')
df['description'].head()
# Out:
# 0    Visit highlights around Corons breathtaking la...
# 1    Learn activitys Enhanced Health Hygiene Measur...
# 2    Book island tour package discover Boracays whi...
# 3    Catch spectacular Boracay sunset cruising alon...
# 4    Explore Puerto Princesa Underground River Nati...
# Name: description, dtype: object

# %% [markdown]
# *Remove punctutations and stop words*

# %%
import string

# Download the NLTK stopwords corpus (only required once)
nltk.download('stopwords')

# Get the set of English stopwords
stopwords_set = set(stopwords.words('english'))

# Function to remove stopwords and punctuation from a text
def remove_stopwords_punctuation(text):
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    # Tokenize the text
    tokens = nltk.word_tokenize(text)
    
    # Remove stopwords
    filtered_tokens = [token for token in tokens if token.lower() not in stopwords_set]
    
    # Join the filtered tokens back into a string
    filtered_text = ' '.join(filtered_tokens)
    
    return filtered_text

# Apply the function to the 'text_column' column
df['description'] = df['description'].apply(remove_stopwords_punctuation)

df['description'].head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 0    Visit highlights around Corons breathtaking la...
# 1    Learn activitys Enhanced Health Hygiene Measur...
# 2    Book island tour package discover Boracays whi...
# 3    Catch spectacular Boracay sunset cruising alon...
# 4    Explore Puerto Princesa Underground River Nati...
# Name: description, dtype: object

# %% [markdown]
# *Separate sentence with spaces*

# %%
# Function to insert spaces before capital letters inside a word
def insert_spaces(text):
    # Use regular expression to find capital letters inside a word
    modified_text = re.sub(r"(\w)([A-Z])", r"\1 \2", text)
    return modified_text

# Apply the function to the 'text_column' column
df['description'] = df['description'].apply(insert_spaces)

df['description'].head()
# Out:
# 0    Visit highlights around Corons breathtaking la...
# 1    Learn activitys Enhanced Health Hygiene Measur...
# 2    Book island tour package discover Boracays whi...
# 3    Catch spectacular Boracay sunset cruising alon...
# 4    Explore Puerto Princesa Underground River Nati...
# Name: description, dtype: object

# %%
df
# Out:
#       region  location             activity
# 0    Visayas   Palawan            Day trips  \
# 1    Visayas      Cebu            Canyoning
# 2    Visayas   Boracay           Boat tours
# 3    Visayas   Boracay  Sightseeing cruises
# 4    Visayas   Palawan           Boat tours
# ..       ...       ...                  ...
# 167    Luzon     Bicol           Boat tours
# 168    Luzon     Tanay             Wildlife
# 169    Luzon     Tanay               Hiking
# 170  Visayas    Carles      Multi-day tours
# 171    Luzon  Antipolo              Camping
#
#                                                  title
# 0                        Coron Super Ultimate Day Tour  \
# 1    Oslob Whale Shark Snorkeling and Badian Canyon...
# 2                Boracay Tour Package (Island Hopping)
# 3    Boracay Sunset Cruise with Kayak, Paddle Board...
# 4    Puerto Princesa Underground River Tour in Palawan
# ..                                                 ...
# 167  Whaleshark Interaction with Firefly Expedition...
# 168                           Moolk Farm Tour in Rizal
# 169      Mount Batolusong Join In Day Hike from Manila
# 170        Gigantes Islands All In Package from Iloilo
# 171          Camping Experience at Gabriel's Sanctuary
#
#                                            description price  rating
# 0    Visit highlights around Corons breathtaking la...  1590     4.7  \
# 1    Learn activitys Enhanced Health Hygiene Measur...  3635     4.7
# 2    Book island tour package discover Boracays whi...   900     4.5
# 3    Catch spectacular Boracay sunset cruising alon...   675     4.7
# 4    Explore Puerto Princesa Underground River Nati...  1850     4.6
# ..                                                 ...   ...     ...
# 167  Donsol best known whale watching makes activit...  2640     3.0
# 168  Experience New Zealand Tanay Rizal see majesti...   499     3.0
# 169  Start morning hiking Mt Batolusong one popular...  1600     3.0
# 170  Enjoy Ultimate Gigantes Islands Package island...  2799     3.0
# 171  Experience camping sky hour away Metro 180 deg...   500     3.0
#
#     review_count  duration
# 0            684       9.0
# 1            798      16.0
# 2          3,947       NaN
# 3          1,517       2.5
# 4          2,478       9.5
# ..           ...       ...
# 167            0       6.0
# 168            0       NaN
# 169            0      24.0
# 170            0      48.0
# 171            0       NaN
#
# [172 rows x 9 columns]

# %%
df.to_csv('pre-processed_klook.csv', index=False)
